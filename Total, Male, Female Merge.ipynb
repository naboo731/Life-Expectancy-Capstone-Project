# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
total = pd.read_csv('format_totalpop.csv')
total.rename(columns={'Avg Life Expectancy': 'Total Pop LE'}, inplace=True)
total.drop(columns=['Unnamed: 0'], inplace=True)
total
# Out:
#           name                                           geometry   longitude  \
# 0         Fiji  MULTIPOLYGON (((180 -16.06713266364245, 180 -1...  179.414413
# 1         Fiji  MULTIPOLYGON (((180 -16.06713266364245, 180 -1...  179.414413
# 2         Fiji  MULTIPOLYGON (((180 -16.06713266364245, 180 -1...  179.414413
# 3         Fiji  MULTIPOLYGON (((180 -16.06713266364245, 180 -1...  179.414413
# 4         Fiji  MULTIPOLYGON (((180 -16.06713266364245, 180 -1...  179.414413
# ...        ...                                                ...         ...
# 9295  S. Sudan  POLYGON ((30.83385242171543 3.509171604222463,...   30.217636
# 9296  S. Sudan  POLYGON ((30.83385242171543 3.509171604222463,...   30.217636
# 9297  S. Sudan  POLYGON ((30.83385242171543 3.509171604222463,...   30.217636
# 9298  S. Sudan  POLYGON ((30.83385242171543 3.509171604222463,...   30.217636
# 9299  S. Sudan  POLYGON ((30.83385242171543 3.509171604222463,...   30.217636
#
# ...

# %%
male_female = pd.read_csv('male_female_formatted.csv')
male_female.drop(columns=['Unnamed: 0'], inplace=True)
male_female
# Out:
#           name   longitude   latitude continent   pop_est  year  \
# 0         Fiji  179.414413 -16.578193   Oceania    920938  1960
# 1         Fiji  179.414413 -16.578193   Oceania    920938  1961
# 2         Fiji  179.414413 -16.578193   Oceania    920938  1962
# 3         Fiji  179.414413 -16.578193   Oceania    920938  1963
# 4         Fiji  179.414413 -16.578193   Oceania    920938  1964
# ...        ...         ...        ...       ...       ...   ...
# 9295  S. Sudan   30.217636  12.862807    Africa  13026129  2015
# 9296  S. Sudan   30.217636  12.862807    Africa  13026129  2016
# 9297  S. Sudan   30.217636  12.862807    Africa  13026129  2017
# 9298  S. Sudan   30.217636  12.862807    Africa  13026129  2018
# 9299  S. Sudan   30.217636  12.862807    Africa  13026129  2019
#
#       Female Life Expectancy  Male Life Expectancy
# 0                     62.369                59.641
# 1                     62.859                59.897
# ...

# %%
complete = pd.merge(male_female, total, on=['name', 'year', 'longitude', 'latitude', 'continent'])
complete.to_csv('all_LE.csv')
