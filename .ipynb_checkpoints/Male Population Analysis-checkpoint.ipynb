# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
male_data = pd.read_csv('males.csv', skiprows=3)
male_data.drop(inplace=True, columns=['Indicator Name', 'Indicator Code', '2020', 'Unnamed: 65'])
male_data.head()
# Out:
#                   Country Name Country Code       1960       1961       1962  \
# 0                        Aruba          ABW  64.084000  64.429000  64.747000
# 1  Africa Eastern and Southern          AFE  41.177958  41.618931  42.049027
# 2                  Afghanistan          AFG  31.718000  32.224000  32.724000
# 3   Africa Western and Central          AFW  36.043028  36.469825  36.890425
# 4                       Angola          AGO  36.305000  36.582000  36.874000
#
#         1963       1964       1965       1966       1967  ...       2010  \
# 0  65.053000  65.356000  65.660000  65.959000  66.242000  ...  72.517000
# 1  42.466545  42.871793  43.266739  43.654421  44.038221  ...  56.580680
# 2  33.216000  33.700000  34.180000  34.656000  35.133000  ...  59.683000
# 3  37.302945  37.706825  38.104684  38.498920  38.894711  ...  53.179092
# 4  37.181000  37.501000  37.833000  38.177000  38.532000  ...  52.848000
#
# ...

# %%
top_male_countries = male_data.groupby('Country Name', as_index=False)['2019'].mean()
top_male_countries.sort_values(by='2019', ascending=False).head(10)
# Out:
#              Country Name    2019
# 103  Hong Kong SAR, China  82.200
# 235           Switzerland  81.900
# 120                 Japan  81.410
# 212             Singapore  81.400
# 234                Sweden  81.300
# 147      Macao SAR, China  81.281
# 182                Norway  81.200
# 44        Channel Islands  81.173
# 118                 Italy  81.100
# 117                Israel  81.000

# %%
bottom_male_countries = male_data.groupby('Country Name', as_index=False)['2019'].mean()
bottom_male_countries.sort_values(by='2019', ascending=True).head(10)
# Out:
#                  Country Name    2019
# 41   Central African Republic  51.081
# 138                   Lesotho  51.201
# 43                       Chad  52.835
# 178                   Nigeria  53.789
# 211              Sierra Leone  53.853
# 218                   Somalia  55.725
# 72                   Eswatini  56.007
# 97              Guinea-Bissau  56.305
# 222               South Sudan  56.351
# 52              Cote d'Ivoire  56.593

# %%
usa = male_data.iloc[251]['1960':'2019']
usa.plot.line()

plt.title('United States', y=1.03)
plt.xlabel('Recorded Year')
plt.ylabel('Life Expectancy (years)')
# Out:
# Text(0, 0.5, 'Life Expectancy (years)')

# %%
swiss = male_data.iloc[235]['1960':'2019']
swiss.plot.line()

plt.title('Switzerland', y=1.03)
plt.xlabel('Recorded Year')
plt.ylabel('Life Expectancy (years)')
# Out:
# Text(0, 0.5, 'Life Expectancy (years)')

# %%
male_data.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# 1960            29
# 1961            28
# 1962            28
#                 ..
# 2015            17
# 2016            17
# 2017            18
# 2018            20
# 2019            20
# Length: 62, dtype: int64

# %%
male_data.dropna(inplace=True, thresh=len(male_data.columns)-45)

# %%
male_data = male_data.interpolate(method ='linear', limit_direction ='forward')
male_data.head(10)
# Out:
#                    Country Name Country Code       1960       1961       1962  \
# 0                         Aruba          ABW  64.084000  64.429000  64.747000
# 1   Africa Eastern and Southern          AFE  41.177958  41.618931  42.049027
# 2                   Afghanistan          AFG  31.718000  32.224000  32.724000
# 3    Africa Western and Central          AFW  36.043028  36.469825  36.890425
# 4                        Angola          AGO  36.305000  36.582000  36.874000
# 5                       Albania          ALB  61.309000  62.272000  63.117000
# 7                    Arab World          ARB  45.504739  46.101725  46.689123
# 8          United Arab Emirates          ARE  49.249000  50.363000  51.462000
# 9                     Argentina          ARG  62.417000  62.460000  62.478000
# 10                      Armenia          ARM  62.822000  63.240000  63.664000
#
#          1963       1964       1965       1966       1967  ...       2010  \
# ...

# %%
male_data.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 1960            0
# 1961            0
# 1962            0
#                ..
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# Length: 62, dtype: int64

# %%
zim = male_data.iloc[246]['1960':'2019']
zim.plot.line()

plt.title('Zimbabwe', y=1.03)
plt.xlabel('Recorded Year')
plt.ylabel('Life Expectancy (years)')
# Out:
# Text(0, 0.5, 'Life Expectancy (years)')

# %%
usa = male_data.iloc[233]['1960':'2019']
usa.plot.line()

plt.title('United States', y=1.03)
plt.xlabel('Recorded Year')
plt.ylabel('Life Expectancy (years)')
# Out:
# Text(0, 0.5, 'Life Expectancy (years)')

# %%
male_data.to_csv('complete_male_data.csv')
male = pd.read_csv('complete_male_data.csv')
male.drop(inplace=True, columns=['Unnamed: 0'])
male.head()
# Out:
#                   Country Name Country Code       1960       1961       1962  \
# 0                        Aruba          ABW  64.084000  64.429000  64.747000
# 1  Africa Eastern and Southern          AFE  41.177958  41.618931  42.049027
# 2                  Afghanistan          AFG  31.718000  32.224000  32.724000
# 3   Africa Western and Central          AFW  36.043028  36.469825  36.890425
# 4                       Angola          AGO  36.305000  36.582000  36.874000
#
#         1963       1964       1965       1966       1967  ...       2010  \
# 0  65.053000  65.356000  65.660000  65.959000  66.242000  ...  72.517000
# 1  42.466545  42.871793  43.266739  43.654421  44.038221  ...  56.580680
# 2  33.216000  33.700000  34.180000  34.656000  35.133000  ...  59.683000
# 3  37.302945  37.706825  38.104684  38.498920  38.894711  ...  53.179092
# 4  37.181000  37.501000  37.833000  38.177000  38.532000  ...  52.848000
#
# ...
